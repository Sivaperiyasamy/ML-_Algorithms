# %% [markdown]
# <a href="https://colab.research.google.com/github/Sivaperiyasamy/ML-_Algorithms/blob/main/Iris_dataset_Adaboost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("/content/Iris.csv")
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.set_index("Id",inplace=True)
data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data['Species']=data['Species'].replace({np.nan:data['Species'].max()})

# %%
mapping = {'Iris-setosa': 1, 'Iris-versicolo': 2, 'Iris-virginica': 3}
data['Species'] = data['Species'].map(mapping)
data['Species'].dtypes
# Out:
# dtype('float64')

# %%
data['Species']=data['Species'].replace(np.nan,2)

# %%
data.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
scalar=MinMaxScaler()

# %%
x=data[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
y=data['Species']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import classification_report

# %% [markdown]
# # # Adaboost Algorithm

# %%
learning_rate=[0.05,0.1,0.25,0.5,0.75,1]
for lr in learning_rate:
  gb=AdaBoostClassifier(n_estimators=20,learning_rate=lr,random_state=0)
  gb.fit(x_train,y_train)
  print("Learning rate: ",lr)a
  print("Accuracy score (train): {0:.3f}".format(gb.score(x_train,y_train)))
  print("Accuracy score (test): {0:.3f}".format(gb.score(x_test,y_test)))
  print()
# Out:
# Learning rate:  0.05
# Accuracy score (train): 0.905
# Accuracy score (test): 0.978
#
# Learning rate:  0.1
# Accuracy score (train): 0.905
# Accuracy score (test): 0.978
#
# Learning rate:  0.25
# Accuracy score (train): 0.905
# Accuracy score (test): 0.978
#
# Learning rate:  0.5
# Accuracy score (train): 0.933
# Accuracy score (test): 1.000
#
# Learning rate:  0.75
# Accuracy score (train): 0.943
# Accuracy score (test): 1.000
#
# Learning rate:  1
# Accuracy score (train): 0.962
# Accuracy score (test): 1.000

# %% [markdown]
# # # Gradient Boost Algorithm

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report

# %%
learning_rate=[0.05,0.1,0.25,0.5,0.75,1]
for lr in learning_rate:
  gb=GradientBoostingClassifier(n_estimators=20,learning_rate=lr,max_features=2,max_depth=2,random_state=0)
  gb.fit(x_train,y_train)
  print("Learning rate: ",lr)
  print("Accuracy score (train): {0:.3f}".format(gb.score(x_train,y_train)))
  print("Accuracy score (test): {0:.3f}".format(gb.score(x_test,y_test)))
  print()
# Out:
# Learning rate:  0.05
# Accuracy score (train): 0.952
# Accuracy score (test): 1.000
#
# Learning rate:  0.1
# Accuracy score (train): 0.962
# Accuracy score (test): 1.000
#
# Learning rate:  0.25
# Accuracy score (train): 1.000
# Accuracy score (test): 1.000
#
# Learning rate:  0.5
# Accuracy score (train): 1.000
# Accuracy score (test): 1.000
#
# Learning rate:  0.75
# Accuracy score (train): 1.000
# Accuracy score (test): 1.000
#
# Learning rate:  1
# Accuracy score (train): 1.000
# Accuracy score (test): 1.000
