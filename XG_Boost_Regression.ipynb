# %% [markdown]
# <a href="https://colab.research.google.com/github/Sivaperiyasamy/ML-_Algorithms/blob/main/XG_Boost_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
test=pd.read_csv("/content/test.csv")
train=pd.read_csv("/content/train.csv")

# %%
test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
train['MSZoning']=lb.fit_transform(train.MSZoning)
train['MSZoning'].isnull().sum()
train['MSZoning'].dtypes
# Out:
# dtype('int64')

# %%
train['LotFrontage'].replace(np.nan,60.0,inplace=True)
train['LotFrontage'].isnull().sum()
# Out:
# 0

# %%
train['Street']=lb.fit_transform(train.Street)
train['Street'].isnull().sum()
train['Street'].dtypes
# Out:
# dtype('int64')

# %%
train.drop('Alley',axis=1,inplace=True)

# %%
train['LotShape']=lb.fit_transform(train.LotShape)
train['LandContour']=lb.fit_transform(train.LandContour)
train['Utilities']=lb.fit_transform(train.Utilities)
train['LotConfig']=lb.fit_transform(train.LotConfig)
train['LandSlope']=lb.fit_transform(train.LandSlope)
train['Neighborhood']=lb.fit_transform(train.Neighborhood)
train['Condition1']=lb.fit_transform(train.Condition1)
train['Condition2']=lb.fit_transform(train.Condition2)
train['BldgType']=lb.fit_transform(train.BldgType)
train['HouseStyle']=lb.fit_transform(train.HouseStyle)
train['RoofStyle']=lb.fit_transform(train.RoofStyle)
train['RoofMatl']=lb.fit_transform(train.RoofMatl)
train['Exterior1st']=lb.fit_transform(train.Exterior1st)
train['Exterior2nd']=lb.fit_transform(train.Exterior2nd)

# %%
train['MasVnrType'].replace(np.nan,'None',inplace=True)
train['MasVnrType']=lb.fit_transform(train.MasVnrType)
train['MasVnrType'].dtypes
train['MasVnrType'].isnull().sum()
# Out:
# 0

# %%
train['ExterQual']=lb.fit_transform(train.ExterQual)
train['ExterCond']=lb.fit_transform(train.ExterCond)
train['Foundation']=lb.fit_transform(train.Foundation)

# %%
mea=train['MasVnrArea'].mean()
train['MasVnrArea'].replace(np.nan,mea,inplace=True)
train['MasVnrArea'].dtypes
train['MasVnrArea'].isnull().sum()
# Out:
# 0

# %%
train['BsmtQual'].replace(np.nan,'TA',inplace=True)
train['BsmtQual']=lb.fit_transform(train.BsmtQual)
train['BsmtQual'].dtypes
train['BsmtQual'].isnull().sum()
# Out:
# 0

# %%
train['BsmtCond'].replace(np.nan,'TA',inplace=True)
train['BsmtCond']=lb.fit_transform(train.BsmtCond)
train['BsmtCond'].dtypes
train['BsmtCond'].isnull().sum()
# Out:
# 0

# %%
train['BsmtExposure'].replace(np.nan,'No',inplace=True)
train['BsmtExposure']=lb.fit_transform(train.BsmtExposure)
train['BsmtExposure'].dtypes
train['BsmtExposure'].isnull().sum()
# Out:
# 0

# %%
train['BsmtFinType1'].replace(np.nan,'Unf',inplace=True)
train['BsmtFinType1']=lb.fit_transform(train.BsmtFinType1)
train['BsmtFinType1'].dtypes
train['BsmtFinType1'].isnull().sum()
# Out:
# 0

# %%
train['BsmtFinType2'].replace(np.nan,'Unf',inplace=True)
train['BsmtFinType2']=lb.fit_transform(train.BsmtFinType2)
train['BsmtFinType2'].dtypes
train['BsmtFinType2'].isnull().sum()
# Out:
# 0

# %%
train['Heating']=lb.fit_transform(train.Heating)
train['HeatingQC']=lb.fit_transform(train.HeatingQC)
train['CentralAir']=lb.fit_transform(train.CentralAir)

# %%
train['Electrical'].replace(np.nan,'SBrkr',inplace=True)
train['Electrical']=lb.fit_transform(train.Electrical)
train['Electrical'].dtypes
train['Electrical'].isnull().sum()
# Out:
# 0

# %%
train['KitchenQual']=lb.fit_transform(train.KitchenQual)
train['Functional']=lb.fit_transform(train.Functional)

# %%
train['FireplaceQu'].mode()
train['FireplaceQu'].replace(np.nan,'Gd',inplace=True)
train['FireplaceQu']=lb.fit_transform(train.FireplaceQu)
train['FireplaceQu'].dtypes
train['FireplaceQu'].isnull().sum()
# Out:
# 0

# %%
train['GarageType'].mode()
train['GarageType'].replace(np.nan,'Attchd',inplace=True)
train['GarageType']=lb.fit_transform(train.GarageType)
train['GarageType'].dtypes
train['GarageType'].isnull().sum()
# Out:
# 0

# %%
train['GarageYrBlt'].mode()
train['GarageType'].replace(np.nan,2005.0,inplace=True)
train['GarageType'].dtypes
train['GarageType'].isnull().sum()
# Out:
# 0

# %%
train['GarageFinish'].mode()
train['GarageFinish'].replace(np.nan,'Unf',inplace=True)
train['GarageFinish']=lb.fit_transform(train.GarageFinish)
train['GarageFinish'].dtypes
train['GarageFinish'].isnull().sum()
# Out:
# 0

# %%
train['GarageQual'].mode()
train['GarageQual'].replace(np.nan,'TA',inplace=True)
train['GarageQual']=lb.fit_transform(train.GarageQual)
train['GarageQual'].dtypes
train['GarageQual'].isnull().sum()
# Out:
# 0

# %%
train['GarageCond'].mode()
train['GarageCond'].replace(np.nan,'TA',inplace=True)
train['GarageCond']=lb.fit_transform(train.GarageQual)
train['GarageCond'].dtypes
train['GarageCond'].isnull().sum()
# Out:
# 0

# %%
train['PavedDrive']=lb.fit_transform(train.PavedDrive)
train['PavedDrive'].dtypes
# Out:
# dtype('int64')

# %%
train.drop('PoolQC',axis=1,inplace=True)

# %%
train['Fence'].mode()
train['Fence'].replace(np.nan,'MnPrv',inplace=True)
train['Fence']=lb.fit_transform(train.Fence)
train['Fence'].dtypes
train['Fence'].isnull().sum()
# Out:
# 0

# %%
train.drop('MiscFeature',axis=1,inplace=True)

# %%
train['SaleType']=lb.fit_transform(train.SaleType)
train['SaleCondition']=lb.fit_transform(train.SaleCondition)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 78 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   LotShape       1460 non-null   int64
#  7   LandContour    1460 non-null   int64
#  8   Utilities      1460 non-null   int64
#  9   LotConfig      1460 non-null   int64
#  10  LandSlope      1460 non-null   int64
#  11  Neighborhood   1460 non-null   int64
#  12  Condition1     1460 non-null   int64
#  13  Condition2     1460 non-null   int64
#  14  BldgType       1460 non-null   int64
#  15  HouseStyle     1460 non-null   int64
#  16  OverallQual    1460 non-null   int64
#  17  OverallCond    1460 non-null   int64
# ...

# %%
x=train.drop(['SalePrice','Id'],axis=1)

# %%
y=train['SalePrice']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.3)

# %%
import xgboost as xgb

# %%
model=xgb.XGBRegressor()

# %%
model.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([145741.64 , 349677.94 , 109485.05 , 188497.4  , 387979.75 ,
#         70712.37 , 220731.08 , 149566.64 ,  85882.29 , 136353.17 ,
#        144041.39 , 126719.336, 107359.91 , 207091.7  , 166266.56 ,
#        133544.97 , 190828.9  , 141211.11 , 126420.875, 195002.08 ,
#        156987.19 , 217900.14 , 175491.22 , 131810.94 , 187275.38 ,
#        177228.34 , 190855.53 ,  98387.53 , 174899.1  , 198912.77 ,
#        132163.31 , 240806.66 , 203069.94 , 114627.28 , 246191.23 ,
#        148602.1  , 118722.95 , 198375.7  , 313920.6  , 128410.55 ,
#        131663.38 , 234525.06 , 127012.086, 383721.28 , 124374.53 ,
#        136072.53 , 108608.89 , 121242.17 , 408319.6  , 130622.55 ,
#        115010.945, 202388.16 , 110476.72 , 316095.97 , 143450.72 ,
#        248253.14 , 196427.58 , 158476.6  , 140168.33 , 104953.87 ,
#         71691.586, 154735.45 , 328196.12 , 347181.22 , 287445.72 ,
#        216877.78 , 120289.54 , 349211.   , 105143.   , 169279.66 ,
# ...

# %%
print("Test score",model.score(x_test,y_test)*100)
# Out:
# Test score 88.97301859323109
